# %%
# %matplotlib inline
from plotlib import plot_bundle_avgs, region_split, bundle_average, MongoCentral, get_mongo_db_client
from IPython import display
from IPython.core.display import display as dplay, HTML
import sys
dplay(HTML("<style>.container { width:100% !important; }</style>"))
root_dir = "/home/nick/project/pymarl/src"
sys.path = [root_dir] + sys.path # adjust to local folder structure


mongo_central = MongoCentral(conf_names=["gandalf_pymarl"], 
                             root_dir=root_dir)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#VDN - ALL AGENTS


#3m 12x12 vdn
data__conv_ddpg_input_grid_3m = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_3m_12x12_vdn_nick_test_2")
print(data__conv_ddpg_input_grid_3m)
data__mathias_3m = mongo_central.get_name_label_names("", "mathias_3m_12x12_vdn_nick_test_2")
data__conv_ddpg_3m = mongo_central.get_name_label_names("", "conv_ddpg_3m_12x12_vdn_nick_test_2")
data__rnn_3m = mongo_central.get_name_label_names("", "rnn_3m_12x12_vdn_nick_test_2")
#data__rnn_input_action_3m = mongo_central.get_name_label_names("", "rnn_input_action_3m_12x12_vdn_nick_test")
bavg_3m = bundle_average(mongo_central, 
                      [("conv_input_flat_agent", data__mathias_3m, "test_battle_won_mean", "test_battle_won_mean_T"),
                       #("rnn_input_agent", data__rnn_input_action_3m, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_agent", data__rnn_3m, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=100000)
bavg2_3m = bundle_average(mongo_central, 
                      [("conv_input_grid_agent", data__conv_ddpg_input_grid_3m, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("conv_agent", data__conv_ddpg_3m, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_agent", data__rnn_3m, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=100000)
a_3m = plot_bundle_avgs(bavg_3m,
                     figsize=(15,8))
b_3m = plot_bundle_avgs(bavg2_3m,
                     figsize=(15,8))




#2s3z 12x12 vdn - needs doing
data__conv_ddpg_input_grid = mongo_central.get_name_label_names("vdn", "conv_ddpg_input_grid_2s3z_12x12_vdn_journal_2")
data__mathias = mongo_central.get_name_label_names("vdn", "mathias_2s3z_12x12_vdn_journal_2")
data__conv_ddpg = mongo_central.get_name_label_names("vdn", "conv_ddpg_2s3z_12x12_vdn_journal_2")
data__rnn = mongo_central.get_name_label_names("vdn", "rnn_2s3z_12x12_vdn_journal_2")
#data__rnn_input_action = mongo_central.get_name_label_names("", "rnn_input_action_2s3z_12x12_vdn_journal")
bavg_2s3z = bundle_average(mongo_central, 
                      [("conv_input_flat_agent", data__mathias, "test_battle_won_mean", "test_battle_won_mean_T"),
                       #("rnn_input_agent", data__rnn_input_action, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_agent", data__rnn, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=100000)
bavg2_2s3z = bundle_average(mongo_central, 
                      [("conv_input_grid_agent", data__conv_ddpg_input_grid, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("conv_agent", data__conv_ddpg, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_agent", data__rnn, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=100000)
a_2s3z = plot_bundle_avgs(bavg_2s3z,
                     figsize=(15,8))
b_2s3z = plot_bundle_avgs(bavg2_2s3z,
                     figsize=(15,8))
# Out:
# Done Loading...
# {'bundle1': [{'name': 'vdn', 'label': 'conv_ddpg_input_grid_3m_12x12_vdn_nick_test_2', '_id': 85980}, {'name': 'vdn', 'label': 'conv_ddpg_input_grid_3m_12x12_vdn_nick_test_2', '_id': 85985}, {'name': 'vdn', 'label': 'conv_ddpg_input_grid_3m_12x12_vdn_nick_test_2', '_id': 85986}, {'name': 'vdn', 'label': 'conv_ddpg_input_grid_3m_12x12_vdn_nick_test_2', '_id': 85992}, {'name': 'vdn', 'label': 'conv_ddpg_input_grid_3m_12x12_vdn_nick_test_2', '_id': 85995}]}
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': 'conv_ddpg_input_grid_2s3z_12x12_vdn_journal_2', '_id': 86006}
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': 'conv_ddpg_2s3z_12x12_vdn_journal_2', '_id': 85999}
# ...

# %%
#QMIX - ALL AGENTS


#3m 12x12 qmix - needs redoing
data__conv_ddpg_input_grid_3m = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_3m_12x12_qmix_journal")
data__mathias_3m = mongo_central.get_name_label_names("", "mathias_3m_12x12_qmix_journal")
data__conv_ddpg_3m = mongo_central.get_name_label_names("", "conv_ddpg_3m_12x12_qmix_journal")
data__rnn_3m = mongo_central.get_name_label_names("", "rnn_3m_12x12_qmix_journal")
data__rnn_input_action_3m = mongo_central.get_name_label_names("", "rnn_input_action_3m_12x12_qmix_journal")
bavg_3m = bundle_average(mongo_central, 
                      [("conv_input_flat_agent", data__mathias_3m, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_input_agent", data__rnn_input_action_3m, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_agent", data__rnn_3m, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=100000)
bavg2_3m = bundle_average(mongo_central, 
                      [("conv_input_grid_agent", data__conv_ddpg_input_grid_3m, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("conv_agent", data__conv_ddpg_3m, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_agent", data__rnn_3m, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=100000)
a_3m = plot_bundle_avgs(bavg_3m,
                     figsize=(15,8))
b_3m = plot_bundle_avgs(bavg2_3m,
                     figsize=(15,8))



#2s3z 12x12 qmix - needs redoing

data__conv_ddpg_input_grid = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_12x12_qmix_journal")
data__mathias = mongo_central.get_name_label_names("", "mathias_2s3z_12x12_qmix_journal")
data__conv_ddpg = mongo_central.get_name_label_names("", "conv_ddpg_2s3z_12x12_qmix_journal")
data__rnn = mongo_central.get_name_label_names("", "rnn_2s3z_12x12_qmix_journal")
#data__rnn_input_action = mongo_central.get_name_label_names("", "rnn_input_action_2s3z_12x12_qmix_journal")
bavg = bundle_average(mongo_central, 
                      [("conv_input_flat_agent", data__mathias, "test_battle_won_mean", "test_battle_won_mean_T"),
                       #("rnn_input_agent", data__rnn_input_action, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_agent", data__rnn, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=100000)
bavg2 = bundle_average(mongo_central, 
                      [("conv_input_grid_agent", data__conv_ddpg_input_grid, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("conv_agent", data__conv_ddpg, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_agent", data__rnn, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=100000)
a = plot_bundle_avgs(bavg,
                     figsize=(15,8))
b = plot_bundle_avgs(bavg2,
                     figsize=(15,8))
# Out:
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Property str not available: test_battle_won_mean not in results for run {'name': 'qmix_journal', 'label': 'mathias_2s3z_12x12_qmix_journal', '_id': 85837}
# Property str not available: test_battle_won_mean not in results for run {'name': 'qmix_journal', 'label': 'mathias_2s3z_12x12_qmix_journal', '_id': 85851}
# Property str not available: test_battle_won_mean not in results for run {'name': 'qmix_journal', 'label': 'mathias_2s3z_12x12_qmix_journal', '_id': 85856}
# Property str not available: test_battle_won_mean not in results for run {'name': 'qmix_journal', 'label': 'mathias_2s3z_12x12_qmix_journal', '_id': 85863}
# Property str not available: test_battle_won_mean not in results for run {'name': 'qmix_journal', 'label': 'mathias_2s3z_12x12_qmix_journal', '_id': 85866}
# ...

# %%
#mult_occ

data__conv_ddpg_input_grid_6 = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_6x6_vdn")
data__conv_ddpg_input_grid_6_mult_occ = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_6x6_vdn_mult_occ")
print(data__conv_ddpg_input_grid_6_mult_occ)
data__conv_ddpg_input_grid_12 = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_12x12_vdn_journal")
data__conv_ddpg_input_grid_12_mult_occ = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_12x12_vdn_journal_mult_occ")
#data__conv_ddpg_input_grid_18 = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_18x18_vdn")
#data__conv_ddpg_input_grid_24 = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_24x24_vdn")
bavg = bundle_average(mongo_central, 
                      [#("24x24", data__conv_ddpg_input_grid_24, "test_battle_won_mean", "test_battle_won_mean_T"),
                       #("18x18", data__conv_ddpg_input_grid_18, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("12x12", data__conv_ddpg_input_grid_12, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("6x6", data__conv_ddpg_input_grid_6, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("6x6 Multiple Occupancy", data__conv_ddpg_input_grid_6_mult_occ, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("12x12 Multiple Occupancy", data__conv_ddpg_input_grid_12_mult_occ, "test_battle_won_mean", "test_battle_won_mean_T"),

                      ], 
                      no_fails=True, 
                      window=100000)

a = plot_bundle_avgs(bavg,
                     figsize=(15,8))
# Out:
# Done Loading...
# Done Loading...
# ...

# %%
#with ID vs no ID, 12x12 VDN - needs doing

#3m
data__conv_ddpg_input_grid_id = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_3m_12x12_vdn_nick_test_2")
data__conv_ddpg_input_grid_noid = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_no_id_2_vdn_3m_12x12")
bavg = bundle_average(mongo_central, 
                      [("Agent ID", data__conv_ddpg_input_grid_id, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("No Agent ID", data__conv_ddpg_input_grid_noid, "test_battle_won_mean", "test_battle_won_mean_T"),
                       #("No Agent ID - VDN", data__conv_ddpg_input_grid_noid_vdn, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=100000)

a = plot_bundle_avgs(bavg,
                     figsize=(15,8))


#2s3z
data__conv_ddpg_input_grid_id_2s3z = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_12x12_vdn_journal")
data__conv_ddpg_input_grid_noid_2s3z = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_no_id_2_vdn_2s3z_12x12")
bavg = bundle_average(mongo_central, 
                      [("Agent ID", data__conv_ddpg_input_grid_id_2s3z, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("No Agent ID", data__conv_ddpg_input_grid_noid_2s3z, "test_battle_won_mean", "test_battle_won_mean_T"),
                       #("No Agent ID - VDN", data__conv_ddpg_input_grid_noid_vdn, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=100000)
a = plot_bundle_avgs(bavg,
                     figsize=(15,8))
# Out:
# Done Loading...
# Done Loading...
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': 'conv_ddpg_input_grid_no_id_2_vdn_3m_12x12', '_id': 86120}
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': 'conv_ddpg_input_grid_no_id_2_vdn_3m_12x12', '_id': 86123}
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': 'conv_ddpg_input_grid_no_id_2_vdn_3m_12x12', '_id': 86124}
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': 'conv_ddpg_input_grid_no_id_2_vdn_3m_12x12', '_id': 86125}
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': 'conv_ddpg_input_grid_no_id_2_vdn_3m_12x12', '_id': 86126}
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': 'conv_ddpg_input_grid_no_id_2_vdn_3m_12x12', '_id': 86128}
# ...

# %%
#QMIX VS VDN
data__conv_ddpg_input_grid_3m_vdn = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_3m_12x12_vdn_nick_test_2")
data__conv_ddpg_input_grid_vdn = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_12x12_vdn_journal_2")
data__conv_ddpg_input_grid_3m_qmix = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_3m_12x12_qmix_journal")
data__conv_ddpg_input_grid_qmix = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_12x12_qmix_journal")
bavg = bundle_average(mongo_central, 
                      [("VDN", data__conv_ddpg_input_grid_3m_vdn, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("QMIX", data__conv_ddpg_input_grid_3m_qmix, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=100000)

a = plot_bundle_avgs(bavg,
                     figsize=(15,8))
bavg2 = bundle_average(mongo_central, 
                      [("VDN", data__conv_ddpg_input_grid_vdn, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("QMIX", data__conv_ddpg_input_grid_qmix, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=100000)

a = plot_bundle_avgs(bavg2,
                     figsize=(15,8))
# Out:
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': 'conv_ddpg_input_grid_2s3z_12x12_vdn_journal_2', '_id': 86006}
# Run (ID 8, name {'name': 'qmix_journal', 'label': 'conv_ddpg_input_grid_2s3z_12x12_qmix_journal', '_id': 85879}) has fail trace!
# Run (ID 9, name {'name': 'qmix_journal', 'label': 'conv_ddpg_input_grid_2s3z_12x12_qmix_journal', '_id': 85885}) has fail trace!
# Run (ID 10, name {'name': 'qmix_journal', 'label': 'conv_ddpg_input_grid_2s3z_12x12_qmix_journal', '_id': 85887}) has fail trace!
# Run (ID 11, name {'name': 'qmix_journal', 'label': 'conv_ddpg_input_grid_2s3z_12x12_qmix_journal', '_id': 85892}) has fail trace!

# %%
#with/without rnn

data__shallow_conv_ddpg_input_grid_noid = mongo_central.get_name_label_names("", "non_rnn_12x12_vdn_noid_2s3z")
data__rnn_conv_ddpg_input_grid_noid = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_no_id_2_vdn_2s3z_12x12")


bavg = bundle_average(mongo_central, 
                      [("Non-RNN", data__shallow_conv_ddpg_input_grid_noid, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("RNN", data__rnn_conv_ddpg_input_grid_noid, "test_battle_won_mean", "test_battle_won_mean_T")

                      ], 
                      no_fails=True, 
                      window=100000)


a = plot_bundle_avgs(bavg,
                     figsize=(15,8))
# Out:
# Done Loading...
# Done Loading...
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': 'non_rnn_12x12_vdn_noid_2s3z', '_id': 86156}
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': 'non_rnn_12x12_vdn_noid_2s3z', '_id': 86157}
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': 'conv_ddpg_input_grid_no_id_2_vdn_2s3z_12x12', '_id': 86133}
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': 'conv_ddpg_input_grid_no_id_2_vdn_2s3z_12x12', '_id': 86134}

# %%
#varying obs


#data__conv_ddpg_input_grid_id = mongo_central.get_name_label_names("", "rnn_conv_ddpg_input_grid_2s3z_12x12_vdn_journal")
data__conv_ddpg_input_grid_no_id = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_no_id_2_vdn_2s3z_12x12")
data__conv_ddpg_input_grid_no_id_no_unit_type = mongo_central.get_name_label_names("", "rnn_conv_ddpg_input_grid_vdn_2s3z_12x12_no_id_no_unit_type")
data__conv_ddpg_input_grid_only_ally_or_enemy = mongo_central.get_name_label_names("", "rnn_conv_ddpg_input_grid_vdn_2s3z_12x12_only_ally_or_enemy")
data__conv_ddpg_input_grid_empty = mongo_central.get_name_label_names("", "rnn_conv_ddpg_input_grid_vdn_2s3z_12x12_empty")

bavg = bundle_average(mongo_central, 
                      [#("Full", data__conv_ddpg_input_grid_id, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("No ID", data__conv_ddpg_input_grid_no_id, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("No ID or unit type", data__conv_ddpg_input_grid_no_id_no_unit_type, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("Only ally or enemy", data__conv_ddpg_input_grid_only_ally_or_enemy, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("empty", data__conv_ddpg_input_grid_empty, "test_battle_won_mean", "test_battle_won_mean_T")

                      ], 
                      no_fails=True, 
                      window=100000)

a = plot_bundle_avgs(bavg,
                     figsize=(15,8))
# Out:
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': 'conv_ddpg_input_grid_no_id_2_vdn_2s3z_12x12', '_id': 86133}
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': 'conv_ddpg_input_grid_no_id_2_vdn_2s3z_12x12', '_id': 86134}
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': 'rnn_conv_ddpg_input_grid_vdn_2s3z_12x12_no_id_no_unit_type', '_id': 86329}

# %%
#conv_ddpg_input_grid_3m_12x12_vdn_short
#conv_ddpg_input_grid_5m_12x12_vdn_short
#conv_ddpg_input_grid_8m_12x12_vdn_short
data__3m = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_3m_12x12_vdn_short")
print(data__3m)
data__5m = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_5m_12x12_vdn_short")
data__8m = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_8m_12x12_vdn_short")


bavg = bundle_average(mongo_central, 
                      [("3m", data__3m, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("5m", data__5m, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("8m", data__8m, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=100000)


a = plot_bundle_avgs(bavg,
                     figsize=(15,8),
                    max_x = 1000000)
# Out:
# Done Loading...
# {'bundle1': [{'name': 'vdn', 'label': 'conv_ddpg_input_grid_3m_12x12_vdn_short', '_id': 86524}, {'name': 'vdn', 'label': 'conv_ddpg_input_grid_3m_12x12_vdn_short', '_id': 86525}, {'name': 'vdn', 'label': 'conv_ddpg_input_grid_3m_12x12_vdn_short', '_id': 86531}, {'name': 'vdn', 'label': 'conv_ddpg_input_grid_3m_12x12_vdn_short', '_id': 86532}, {'name': 'vdn', 'label': 'conv_ddpg_input_grid_3m_12x12_vdn_short', '_id': 86535}, {'name': 'vdn', 'label': 'conv_ddpg_input_grid_3m_12x12_vdn_short', '_id': 86536}, {'name': 'vdn', 'label': 'conv_ddpg_input_grid_3m_12x12_vdn_short', '_id': 86542}, {'name': 'vdn', 'label': 'conv_ddpg_input_grid_3m_12x12_vdn_short', '_id': 86544}]}
# Done Loading...
# Done Loading...

# %%
#Transfer
data__3m_to_5m_200000 = mongo_central.get_name_label_names("", "3m_to_5m_200000")
print(data__3m_to_5m_200000)
data__5m_to_8m_200000 = mongo_central.get_name_label_names("", "5m_to_8m_200000")
data__5m_to_3m_200000 = mongo_central.get_name_label_names("", "5m_to_3m_200000")
data__8m_to_5m_200000 = mongo_central.get_name_label_names("", "8m_to_5m_200000")
data__3m = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_3m_12x12_vdn_short")
data__5m = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_5m_12x12_vdn_short")
data__8m = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_8m_12x12_vdn_short")

bavg1 = bundle_average(mongo_central, 
                      [("3m to 5m 200000", data__3m_to_5m_200000, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("5m", data__5m, "test_battle_won_mean", "test_battle_won_mean_T"),
                      ], 
                      no_fails=True, 
                      window=100000)


a = plot_bundle_avgs(bavg1,
                     figsize=(15,8),
                    max_x = 1000000)

bavg2 = bundle_average(mongo_central, 
                      [("5m to 8m 200000", data__5m_to_8m_200000, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("8m", data__8m, "test_battle_won_mean", "test_battle_won_mean_T"),
                      ], 
                      no_fails=True, 
                      window=100000)


a = plot_bundle_avgs(bavg2,
                     figsize=(15,8),
                    max_x = 1000000)

bavg3 = bundle_average(mongo_central, 
                      [("5m to 3m 200000", data__5m_to_3m_200000, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("3m", data__3m, "test_battle_won_mean", "test_battle_won_mean_T"),
                      ], 
                      no_fails=True, 
                      window=100000)


a = plot_bundle_avgs(bavg3,
                     figsize=(15,8),
                    max_x = 1000000)

bavg4 = bundle_average(mongo_central, 
                      [("8m to 5m 200000", data__8m_to_5m_200000, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("5m", data__5m, "test_battle_won_mean", "test_battle_won_mean_T"),
                      ], 
                      no_fails=True, 
                      window=100000)

a = plot_bundle_avgs(bavg4,
                     figsize=(15,8),
                    max_x = 1000000)
# Out:
# Done Loading...
# {'bundle1': [{'name': 'vdn', 'label': '3m_to_5m_200000', '_id': 86871}, {'name': 'vdn', 'label': '3m_to_5m_200000', '_id': 86874}, {'name': 'vdn', 'label': '3m_to_5m_200000', '_id': 87341}, {'name': 'vdn', 'label': '3m_to_5m_200000', '_id': 87342}, {'name': 'vdn', 'label': '3m_to_5m_200000', '_id': 87352}, {'name': 'vdn', 'label': '3m_to_5m_200000', '_id': 87353}]}
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': '3m_to_5m_200000', '_id': 87341}
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': '3m_to_5m_200000', '_id': 87342}
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': '3m_to_5m_200000', '_id': 87352}
# ...

# %%
#Transfer - NEED TO CHANGE 200000 to 600000
data__3m_to_5m_200000 = mongo_central.get_name_label_names("", "3m_to_5m_600000")

data__5m_to_8m_200000 = mongo_central.get_name_label_names("", "5m_to_8m_600000")
data__5m_to_3m_200000 = mongo_central.get_name_label_names("", "5m_to_3m_600000")
data__8m_to_5m_200000 = mongo_central.get_name_label_names("", "8m_to_5m_600000")
data__3m = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_3m_12x12_vdn_short")
data__5m = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_5m_12x12_vdn_short")
data__8m = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_8m_12x12_vdn_short")

bavg1 = bundle_average(mongo_central, 
                      [("3m to 5m 600000", data__3m_to_5m_200000, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("5m", data__5m, "test_battle_won_mean", "test_battle_won_mean_T"),
                      ], 
                      no_fails=True, 
                      window=100000)


a = plot_bundle_avgs(bavg1,
                     figsize=(15,8),
                    max_x = 1000000)

bavg2 = bundle_average(mongo_central, 
                      [("5m to 8m 600000", data__5m_to_8m_200000, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("8m", data__8m, "test_battle_won_mean", "test_battle_won_mean_T"),
                      ], 
                      no_fails=True, 
                      window=100000)


a = plot_bundle_avgs(bavg2,
                     figsize=(15,8),
                    max_x = 1000000)

bavg3 = bundle_average(mongo_central, 
                      [("5m to 3m 600000", data__5m_to_3m_200000, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("3m", data__3m, "test_battle_won_mean", "test_battle_won_mean_T"),
                      ], 
                      no_fails=True, 
                      window=100000)


a = plot_bundle_avgs(bavg3,
                     figsize=(15,8),
                    max_x = 1000000)

bavg4 = bundle_average(mongo_central, 
                      [("8m to 5m 600000", data__8m_to_5m_200000, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("5m", data__5m, "test_battle_won_mean", "test_battle_won_mean_T"),
                      ], 
                      no_fails=True, 
                      window=100000)

a = plot_bundle_avgs(bavg4,
                     figsize=(15,8),
                    max_x = 1000000)
# Out:
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': '3m_to_5m_600000', '_id': 87314}
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': '3m_to_5m_600000', '_id': 87315}
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': '3m_to_5m_600000', '_id': 87320}
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': '3m_to_5m_600000', '_id': 87321}
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': '3m_to_5m_600000', '_id': 87329}
# Property str not available: test_battle_won_mean not in results for run {'name': 'vdn', 'label': '3m_to_5m_600000', '_id': 87331}
# ...

# %%
#Dual training
data__test = mongo_central.get_name_label_names("", "3m_and_5m_reptile2")
print(data__test)

bavg1 = bundle_average(mongo_central, 
                      [("5m and 3m", data__test, "test_battle_won_mean", "test_battle_won_mean_T"),
                      ], 
                      no_fails=True, 
                      window=100000)


a = plot_bundle_avgs(bavg1,
                     figsize=(15,8))
# Out:
# Done Loading...
# ...
