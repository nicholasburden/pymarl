# %%
# %matplotlib inline
from plotlib import plot_bundle_avgs, region_split, bundle_average, MongoCentral, get_mongo_db_client
from IPython import display
from IPython.core.display import display as dplay, HTML
import sys
dplay(HTML("<style>.container { width:100% !important; }</style>"))
root_dir = "/home/nick/Project/pymarl/src"
sys.path = [root_dir] + sys.path # adjust to local folder structure
# Out:
# <style>.container { width:100% !important; }</style>

# %%
mongo_central = MongoCentral(conf_names=["gandalf_pymarl"], 
                             root_dir=root_dir)

# %%
#2s3z 12x12 qmix


data__conv_ddpg_input_grid = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_12x12_qmix_nick")
print(data__conv_ddpg_input_grid)

data__mathias = mongo_central.get_name_label_names("", "mathias_2s3z_12x12_qmix_nick")
print(data__mathias)

data__conv_ddpg = mongo_central.get_name_label_names("", "conv_ddpg_2s3z_12x12_qmix_nick")
print(data__conv_ddpg)

data__rnn = mongo_central.get_name_label_names("", "rnn_2s3z_12x12_qmix_nick")
print(data__rnn)

data__rnn_input_action = mongo_central.get_name_label_names("", "rnn_input_action_2s3z_12x12_qmix_nick")
print(data__rnn_input_action)


bavg = bundle_average(mongo_central, 
                      [("conv_input_grid_agent", data__conv_ddpg_input_grid, "test_battle_won_mean", "test_battle_won_mean_T"),
                      ("conv_input_flat_agent", data__mathias, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("conv_agent", data__conv_ddpg, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_agent", data__rnn, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_input_agent", data__rnn_input_action, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=20000)

a = plot_bundle_avgs(bavg,
                     figsize=(10,5))
# Out:
# Done Loading...
# {'bundle1': [{'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_2s3z_12x12_qmix_nick', '_id': 83924}, {'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_2s3z_12x12_qmix_nick', '_id': 83926}, {'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_2s3z_12x12_qmix_nick', '_id': 83934}]}
# Done Loading...
# {'bundle1': [{'name': 'qmix_smac_parallel', 'label': 'mathias_2s3z_12x12_qmix_nick', '_id': 83921}, {'name': 'qmix_smac_parallel', 'label': 'mathias_2s3z_12x12_qmix_nick', '_id': 83928}, {'name': 'qmix_smac_parallel', 'label': 'mathias_2s3z_12x12_qmix_nick', '_id': 83930}]}
# Done Loading...
# {'bundle1': [{'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_2s3z_12x12_qmix_nick', '_id': 83923}, {'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_2s3z_12x12_qmix_nick', '_id': 83929}, {'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_2s3z_12x12_qmix_nick', '_id': 83931}]}
# Done Loading...
# ...

# %%
#3m 12x12 qmix

data__conv_ddpg_input_grid = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_3m_12x12_qmix_nick")
print(data__conv_ddpg_input_grid)

data__mathias = mongo_central.get_name_label_names("", "mathias_3m_12x12_qmix_nick")
print(data__mathias)

data__conv_ddpg = mongo_central.get_name_label_names("", "conv_ddpg_3m_12x12_qmix_nick")
print(data__conv_ddpg)

data__rnn = mongo_central.get_name_label_names("", "rnn_3m_12x12_qmix_nick")
print(data__rnn)

data__rnn_input_action = mongo_central.get_name_label_names("", "rnn_input_action_3m_12x12_qmix_nick")
print(data__rnn_input_action)

bavg = bundle_average(mongo_central, 
                      [("conv_input_grid_agent", data__conv_ddpg_input_grid, "test_battle_won_mean", "test_battle_won_mean_T"),
                      ("conv_input_flat_agent", data__mathias, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("conv_agent", data__conv_ddpg, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_agent", data__rnn, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_input_agent", data__rnn_input_action, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=20000)

a = plot_bundle_avgs(bavg,
                     figsize=(10,5))

# %%
#2s3z 8x8, 12x12, 16x16, 24x24 qmix

data__conv_ddpg_input_grid_8 = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_8x8_qmix_nick")
print(data__conv_ddpg_input_grid_8)

data__conv_ddpg_input_grid_12 = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_12x12_qmix_nick")
print(data__conv_ddpg_input_grid_12)

data__conv_ddpg_input_grid_16 = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_16x16_qmix_nick")
print(data__conv_ddpg_input_grid_16)

data__conv_ddpg_input_grid_24 = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_24x24_qmix_nick")
print(data__conv_ddpg_input_grid_24

bavg = bundle_average(mongo_central, 
                      [("8x8", data__conv_ddpg_input_grid_8, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("12x12", data__conv_ddpg_input_grid_12, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("16x16", data__conv_ddpg_input_grid_16, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("24x24", data__conv_ddpg_input_grid_24, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=20000)

a = plot_bundle_avgs(bavg,
                     figsize=(10,5))

# %%
#with ID vs no ID, YxY qmix

data__conv_ddpg_input_grid_id = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_YxY_qmix_nick")
print(data__conv_ddpg_input_grid_id)

data__conv_ddpg_input_grid_noid = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_no_id_2s3z_YxY_qmix_nick")
print(data__conv_ddpg_input_grid_noid)



bavg = bundle_average(mongo_central, 
                      [("Agent ID", data__conv_ddpg_input_grid_id, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("No Agent ID", data__conv_ddpg_input_grid_noid, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=20000)

a = plot_bundle_avgs(bavg,
                     figsize=(10,5))
