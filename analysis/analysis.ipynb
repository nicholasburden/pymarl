# %%
# %matplotlib inline
from plotlib import plot_bundle_avgs, region_split, bundle_average, MongoCentral, get_mongo_db_client
from IPython import display
from IPython.core.display import display as dplay, HTML
import sys
dplay(HTML("<style>.container { width:100% !important; }</style>"))
root_dir = "/home/nick/project/pymarl/src"
sys.path = [root_dir] + sys.path # adjust to local folder structure


mongo_central = MongoCentral(conf_names=["gandalf_pymarl"], 
                             root_dir=root_dir)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#2s3z 12x12 qmix
#done

data__conv_ddpg_input_grid = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_12x12_qmix_nick_test_2")
print(data__conv_ddpg_input_grid)

data__mathias = mongo_central.get_name_label_names("", "mathias_2s3z_12x12_qmix_nick_test_2")
print(data__mathias)

data__conv_ddpg = mongo_central.get_name_label_names("", "conv_ddpg_2s3z_12x12_qmix_nick_test_2")
print(data__conv_ddpg)

data__rnn = mongo_central.get_name_label_names("", "rnn_2s3z_12x12_qmix_nick_test_2")
print(data__rnn)

data__rnn_input_action = mongo_central.get_name_label_names("", "rnn_input_action_2s3z_12x12_qmix_nick_test_2")
print(data__rnn_input_action)


bavg = bundle_average(mongo_central, 
                      [("conv_input_flat_agent", data__mathias, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_input_agent", data__rnn_input_action, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_agent", data__rnn, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=20000)

bavg2 = bundle_average(mongo_central, 
                      [("conv_input_grid_agent", data__conv_ddpg_input_grid, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("conv_agent", data__conv_ddpg, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_agent", data__rnn, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=100000)

a = plot_bundle_avgs(bavg,
                     figsize=(15,8))

b = plot_bundle_avgs(bavg2,
                     figsize=(15,8))
# Out:
# Done Loading...
# ...

# %%
#2s3z 12x12 vdn
#run again for 10M

data__conv_ddpg_input_grid = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_12x12_vdn_nick_test")
print(data__conv_ddpg_input_grid)

data__mathias = mongo_central.get_name_label_names("", "mathias_2s3z_12x12_vdn_nick_test")
print(data__mathias)

data__conv_ddpg = mongo_central.get_name_label_names("", "conv_ddpg_2s3z_12x12_vdn_nick_test")
print(data__conv_ddpg)

data__rnn = mongo_central.get_name_label_names("", "rnn_2s3z_12x12_vdn_nick_test")
print(data__rnn)

data__rnn_input_action = mongo_central.get_name_label_names("", "rnn_input_action_2s3z_12x12_vdn_nick_test")
print(data__rnn_input_action)


bavg = bundle_average(mongo_central, 
                      [("conv_input_flat_agent", data__mathias, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_input_agent", data__rnn_input_action, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_agent", data__rnn, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=20000)

bavg2 = bundle_average(mongo_central, 
                      [("conv_input_grid_agent", data__conv_ddpg_input_grid, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("conv_agent", data__conv_ddpg, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_agent", data__rnn, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=20000)

a = plot_bundle_avgs(bavg,
                     figsize=(15,8))

b = plot_bundle_avgs(bavg2,
                     figsize=(15,8))
# Out:
# Done Loading...
# ...

# %%
#3m 24x24 vdn
#done
data__conv_ddpg_input_grid = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_3m_vdn_nick")
print(data__conv_ddpg_input_grid)

data__mathias = mongo_central.get_name_label_names("", "mathias_3m_vdn_nick")
print(data__mathias)

data__conv_ddpg = mongo_central.get_name_label_names("", "conv_ddpg_3m_vdn_nick")
print(data__conv_ddpg)

data__rnn = mongo_central.get_name_label_names("", "rnn_3m_vdn_nick")
print(data__rnn)

data__rnn_input_action = mongo_central.get_name_label_names("", "label=rnn_input_action_3m_vdn_nick")
print(data__rnn_input_action)

bavg = bundle_average(mongo_central, 
                      [("conv_input_flat_agent", data__mathias, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_input_agent", data__rnn_input_action, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_agent", data__rnn, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=20000)

bavg2 = bundle_average(mongo_central, 
                      [("conv_input_grid_agent", data__conv_ddpg_input_grid, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("conv_agent", data__conv_ddpg, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_agent", data__rnn, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=20000)

a = plot_bundle_avgs(bavg,
                     figsize=(15,8))

b = plot_bundle_avgs(bavg2,
                     figsize=(15,8))
# Out:
# Done Loading...
# {'bundle1': [{'name': 'conv_ddpg_input_grid_3m_vdn_nick', 'label': 'conv_ddpg_input_grid_3m_vdn_nick', '_id': 82302}, {'name': 'conv_ddpg_input_grid_3m_vdn_nick', 'label': 'conv_ddpg_input_grid_3m_vdn_nick', '_id': 82304}, {'name': 'conv_ddpg_input_grid_3m_vdn_nick', 'label': 'conv_ddpg_input_grid_3m_vdn_nick', '_id': 82305}, {'name': 'conv_ddpg_input_grid_3m_vdn_nick', 'label': 'conv_ddpg_input_grid_3m_vdn_nick', '_id': 82306}, {'name': 'conv_ddpg_input_grid_3m_vdn_nick', 'label': 'conv_ddpg_input_grid_3m_vdn_nick', '_id': 82307}]}
# Done Loading...
# {'bundle1': [{'name': 'vdn_smac_parallel', 'label': 'mathias_3m_vdn_nick', '_id': 82512}, {'name': 'vdn_smac_parallel', 'label': 'mathias_3m_vdn_nick', '_id': 82513}, {'name': 'vdn_smac_parallel', 'label': 'mathias_3m_vdn_nick', '_id': 82514}, {'name': 'vdn_smac_parallel', 'label': 'mathias_3m_vdn_nick', '_id': 82515}, {'name': 'vdn_smac_parallel', 'label': 'mathias_3m_vdn_nick', '_id': 82516}]}
# Done Loading...
# ...

# %%
#3m 24x24 qmix

#done, trim at around 2,000,0000

data__conv_ddpg_input_grid = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_3m_24x24_qmix_nick_test")
print(data__conv_ddpg_input_grid)

data__mathias = mongo_central.get_name_label_names("", "mathias_3m_24x24_qmix_nick_test")
print(data__mathias)

data__conv_ddpg = mongo_central.get_name_label_names("", "conv_ddpg_3m_24x24_qmix_nick_test")
print(data__conv_ddpg)

data__rnn = mongo_central.get_name_label_names("", "rnn_3m_24x24_qmix_nick_test")
print(data__rnn)

data__rnn_input_action = mongo_central.get_name_label_names("", "rnn_input_action_3m_24x24_qmix_nick_test")
print(data__rnn_input_action)

bavg = bundle_average(mongo_central, 
                      [("conv_input_flat_agent", data__mathias, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_input_agent", data__rnn_input_action, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_agent", data__rnn, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=20000)

bavg2 = bundle_average(mongo_central, 
                      [("conv_input_grid_agent", data__conv_ddpg_input_grid, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("conv_agent", data__conv_ddpg, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_agent", data__rnn, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=20000)

a = plot_bundle_avgs(bavg,
                     figsize=(15,8))

b = plot_bundle_avgs(bavg2,
                     figsize=(15,8))
# Out:
# Done Loading...
# {'bundle1': [{'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_3m_24x24_qmix_nick_test', '_id': 84371}, {'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_3m_24x24_qmix_nick_test', '_id': 84372}, {'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_3m_24x24_qmix_nick_test', '_id': 84378}, {'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_3m_24x24_qmix_nick_test', '_id': 84384}, {'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_3m_24x24_qmix_nick_test', '_id': 84388}, {'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_3m_24x24_qmix_nick_test', '_id': 84393}, {'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_3m_24x24_qmix_nick_test', '_id': 84396}, {'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_3m_24x24_qmix_nick_test', '_id': 84403}, {'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_3m_24x24_qmix_nick_test', '_id': 84405}]}
# Done Loading...
# ...

# %%
#3m 12x12 qmix
#dont think I need this
data__conv_ddpg_input_grid = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_3m_12x12_qmix_nick_test")
print(data__conv_ddpg_input_grid)

data__mathias = mongo_central.get_name_label_names("", "mathias_3m_12x12_qmix_nick_test")
print(data__mathias)

data__conv_ddpg = mongo_central.get_name_label_names("", "conv_ddpg_3m_12x12_qmix_nick_test")
print(data__conv_ddpg)

data__rnn = mongo_central.get_name_label_names("", "rnn_3m_12x12_qmix_nick_test")
print(data__rnn)

data__rnn_input_action = mongo_central.get_name_label_names("", "rnn_input_action_3m_12x12_qmix_nick_test")
print(data__rnn_input_action)

bavg = bundle_average(mongo_central, 
                      [("conv_input_flat_agent", data__mathias, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_input_agent", data__rnn_input_action, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_agent", data__rnn, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=20000)

bavg2 = bundle_average(mongo_central, 
                      [("conv_input_grid_agent", data__conv_ddpg_input_grid, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("conv_agent", data__conv_ddpg, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn_agent", data__rnn, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=20000)

a = plot_bundle_avgs(bavg,
                     figsize=(15,8))

b = plot_bundle_avgs(bavg2,
                     figsize=(15,8))
# Out:
# Done Loading...
# {'bundle1': [{'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_3m_12x12_qmix_nick_test', '_id': 84255}, {'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_3m_12x12_qmix_nick_test', '_id': 84260}, {'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_3m_12x12_qmix_nick_test', '_id': 84264}, {'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_3m_12x12_qmix_nick_test', '_id': 84269}, {'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_3m_12x12_qmix_nick_test', '_id': 84283}]}
# Done Loading...
# ...

# %%
#2s3z 8x8, 12x12, 16x16, 24x24 qmix
#done , needs trimming)

data__conv_ddpg_input_grid_6 = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_6x6_qmix_nick")
#print(data__conv_ddpg_input_grid_6)

data__conv_ddpg_input_grid_12 = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_12x12_qmix_nick_test_2")
#print(data__conv_ddpg_input_grid_12)

data__conv_ddpg_input_grid_18 = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_18x18_qmix_nick")
#print(data__conv_ddpg_input_grid_18)

data__conv_ddpg_input_grid_24 = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_24x24_qmix_nick")
#print(data__conv_ddpg_input_grid_24)

bavg = bundle_average(mongo_central, 
                      [("24x24", data__conv_ddpg_input_grid_24, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("18x18", data__conv_ddpg_input_grid_18, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("12x12", data__conv_ddpg_input_grid_12, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("6x6", data__conv_ddpg_input_grid_6, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=20000)

a = plot_bundle_avgs(bavg,
                     figsize=(15,8))
# Out:
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Property str not available: test_battle_won_mean not in results for run {'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_2s3z_24x24_qmix_nick', '_id': 84617}
# Property str not available: test_battle_won_mean not in results for run {'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_2s3z_24x24_qmix_nick', '_id': 84619}
# Run (ID 5, name {'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_2s3z_24x24_qmix_nick', '_id': 84643}) has fail trace!
# Run (ID 8, name {'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_2s3z_24x24_qmix_nick', '_id': 84646}) has fail trace!
# Run (ID 10, name {'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_2s3z_24x24_qmix_nick', '_id': 84651}) has fail trace!
# Property str not available: test_battle_won_mean not in results for run {'name': 'qmix_smac_parallel', 'label': 'conv_ddpg_input_grid_2s3z_24x24_qmix_nick', '_id': 84657}
# ...

# %%
#with ID vs no ID, 24x24 qmix
#done, trim

data__conv_ddpg_input_grid_id = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_24x24_qmix_nick")
print(data__conv_ddpg_input_grid_id)

data__conv_ddpg_input_grid_noid_qmix = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_no_id_2_qmix_2s3z_24x24")
print(data__conv_ddpg_input_grid_noid_qmix)

#data__conv_ddpg_input_grid_noid_vdn = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_no_id_2_vdn_2s3z_24x24")
#print(data__conv_ddpg_input_grid_noid_vdn)


bavg = bundle_average(mongo_central, 
                      [("Agent ID", data__conv_ddpg_input_grid_id, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("No Agent ID - QMIX", data__conv_ddpg_input_grid_noid_qmix, "test_battle_won_mean", "test_battle_won_mean_T"),
                       #("No Agent ID - VDN", data__conv_ddpg_input_grid_noid_vdn, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=20000)

a = plot_bundle_avgs(bavg,
                     figsize=(15,8))
# Out:
# Done Loading...
# ...

# %%
#non-recurrent on 2s3z
data__conv_ddpg_input_grid_noid = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_no_id_2_qmix_2s3z_24x24")


data__conv_ddpg_input_grid_id = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_2s3z_24x24_qmix_nick")
data__conv_ddpg_input_grid_deep = mongo_central.get_name_label_names("", "non_recurrent_deep_24x24_qmix")
data__conv_ddpg_input_grid_shallow = mongo_central.get_name_label_names("", "non_recurrent_shallow_24x24_qmix")
data__conv_ddpg_input_grid_deep_noid = mongo_central.get_name_label_names("", "non_recurrent_deep_24x24_qmix_no_id")
data__conv_ddpg_input_grid_shallow_noid = mongo_central.get_name_label_names("", "non_recurrent_shallow_24x24_qmix_no_id")

#data__conv_ddpg_input_grid_noid_vdn = mongo_central.get_name_label_names("", "conv_ddpg_input_grid_no_id_2_vdn_2s3z_24x24")
#print(data__conv_ddpg_input_grid_noid_vdn)


bavg = bundle_average(mongo_central, 
                      [#("Deep", data__conv_ddpg_input_grid_deep, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("Without GRU-Cell", data__conv_ddpg_input_grid_shallow_noid, "test_battle_won_mean", "test_battle_won_mean_T"),
                       #("Deep no id", data__conv_ddpg_input_grid_deep_noid, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("With GRU-Cell", data__conv_ddpg_input_grid_noid, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=20000)

a = plot_bundle_avgs(bavg,
                     figsize=(15,8))
# Out:
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...

# %%
#non recurrent without id or unit type

data__conv_ddpg_input_grid_shallow_noid_nounittype = mongo_central.get_name_label_names("", "non_recurrent_shallow_24x24_qmix_noid_nounittype")
data__conv_ddpg_input_grid_shallow_noid = mongo_central.get_name_label_names("", "non_recurrent_shallow_24x24_qmix_no_id")
data__conv_ddpg_input_grid_shallow_only_ally_or_enemy = mongo_central.get_name_label_names("", "non_recurrent_shallow_24x24_qmix_only_ally_or_enemy")
data__conv_ddpg_input_grid_shallow_empty = mongo_central.get_name_label_names("", "non_recurrent_shallow_24x24_qmix_empty")


bavg = bundle_average(mongo_central, 
                      [("No ID or Unit Type", data__conv_ddpg_input_grid_shallow_noid_nounittype, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("NoID", data__conv_ddpg_input_grid_shallow_noid, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("Only ally_or_enemy", data__conv_ddpg_input_grid_shallow_only_ally_or_enemy, "test_battle_won_mean", "test_battle_won_mean_T"),
                       #("empty", data__conv_ddpg_input_grid_shallow_empty, "test_battle_won_mean", "test_battle_won_mean_T")

                      ], 
                      no_fails=True, 
                      window=20000)


bavg2 = bundle_average(mongo_central, 
                      [("empty", data__conv_ddpg_input_grid_shallow_empty, "test_battle_won_mean", "test_battle_won_mean_T")], 
                      no_fails=True, 
                      window=20000)

a = plot_bundle_avgs(bavg,
                     figsize=(15,8))
b = plot_bundle_avgs(bavg2,
                     figsize=(15,8))
# Out:
# Done Loading...
# Done Loading...
# Done Loading...
# Done Loading...
# Property str not available: test_battle_won_mean not in results for run {'name': 'qmix_smac_parallel', 'label': 'non_recurrent_shallow_24x24_qmix_empty', '_id': 85017}
# Property str not available: test_battle_won_mean not in results for run {'name': 'qmix_smac_parallel', 'label': 'non_recurrent_shallow_24x24_qmix_empty', '_id': 85018}

# %%
#conv_input_flat on empty obs

data__rnn_conv_ddpg_2s3z_24x24_qmix_empty = mongo_central.get_name_label_names("", "rnn_conv_ddpg_2s3z_24x24_qmix_empty")
data__conv_ddpg_2s3z_24x24_qmix_empty = mongo_central.get_name_label_names("", "non_rnn_conv_ddpg_2s3z_24x24_qmix_empty")



bavg = bundle_average(mongo_central, 
                      [#("no id or unit type", data__conv_ddpg_input_grid_shallow_noid_nounittype, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("rnn conv empty obs", data__rnn_conv_ddpg_2s3z_24x24_qmix_empty, "test_battle_won_mean", "test_battle_won_mean_T"),
                       ("conv empty obs", data__conv_ddpg_2s3z_24x24_qmix_empty, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=20000)

a = plot_bundle_avgs(bavg,
                     figsize=(15,8))
# Out:
# Done Loading...
# Done Loading...
# Property str not available: test_battle_won_mean not in results for run {'name': 'qmix_smac_parallel', 'label': 'rnn_conv_ddpg_2s3z_24x24_qmix_empty', '_id': 85084}
# Property str not available: test_battle_won_mean not in results for run {'name': 'qmix_smac_parallel', 'label': 'rnn_conv_ddpg_2s3z_24x24_qmix_empty', '_id': 85086}
# Property str not available: test_battle_won_mean not in results for run {'name': 'qmix_smac_parallel', 'label': 'non_rnn_conv_ddpg_2s3z_24x24_qmix_empty', '_id': 85081}
# Property str not available: test_battle_won_mean not in results for run {'name': 'qmix_smac_parallel', 'label': 'non_rnn_conv_ddpg_2s3z_24x24_qmix_empty', '_id': 85082}
# Property str not available: test_battle_won_mean not in results for run {'name': 'qmix_smac_parallel', 'label': 'non_rnn_conv_ddpg_2s3z_24x24_qmix_empty', '_id': 85083}
# ...

# %%
#3s5z rnn vs non rnn

data__rnnconv_input_grid_12x12_qmix_3s5z = mongo_central.get_name_label_names("", "conv_input_grid_12x12_qmix_3s5z")
data__non_rnn_conv_input_grid_12x12_qmix_3s5z = mongo_central.get_name_label_names("", "non_rnn_conv_input_grid_12x12_qmix_3s5z")
data__rnn_3s5z_qmix = mongo_central.get_name_label_names("", "rnn_3s5z_qmix")



bavg = bundle_average(mongo_central, 
                      [("rnn", data__rnn_3s5z_qmix, "test_battle_won_mean", "test_battle_won_mean_T"),
                       #("conv_input_grid_24x24_qmix_3s5z", data__rnnconv_input_grid_12x12_qmix_3s5z, "test_battle_won_mean", "test_battle_won_mean_T"),
                       #("non_rnn_conv_input_grid_12x12_qmix_3s5z", data__non_rnn_conv_input_grid_12x12_qmix_3s5z, "test_battle_won_mean", "test_battle_won_mean_T")
                      ], 
                      no_fails=True, 
                      window=20000)

a = plot_bundle_avgs(bavg,
                     figsize=(15,8))
# Out:
# Done Loading...
# Done Loading...
# Done Loading...
